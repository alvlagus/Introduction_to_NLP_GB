# %% [markdown]
# <h1 align='center'>Введение в обработку естественного языка</h1>
# <h2 align='center'>Курсовой проект</h2>
#
# <h3 align='left'>Курсовой проект</h3>
#
# Реализовать диалоговую систему в виде Телеграмм бота.
#
# Основное задание - сделать проактивный алгоритм, который на фразу дает релевантный ответ
